# %%
#1 Python program to sum all the items in a list
x = 0
list = [4, 15, 27, 38, 43, 55]
for ele in range(0, len(list)):
    x = x + list[ele]
print("Sum of all elements in given list: ", x)
# Out:
# Sum of all elements in given list:  182

# %%
#2 Python program to multiplies all the items in a list
l = [5, 10, 15]
def multiplyList(myList):
    result = 1
    for x in myList:
        result = result * x
    return result
print(multiplyList(l))
# Out:
# 750

# %%
#3 Python program to get the largest number from a list
l = [3, 29, 14, 45, 105, 57, 98, 10, 42, 31 ]
l.sort()
print("Largest element is:", l[-1])
# Out:
# Largest element is: 105

# %%
#4 Python program to get the smallest number from a list
l = [13, 29, 14, 45, 2, 105, 57, 98, 10, 42, 31 ]
l.sort()
print("Smallest element is:", l[0])
# Out:
# Smallest element is: 2

# %%
#5 Python program to count the number of characters in a string
str1 = 'google.com'
x = len(str1)
print("Count of characters : ", x)
# Out:
# Count of characters :  10

# %%
#6 Python function that takes a list of words and returns the length of the longest one
a = ["C", "C++", "Java", "Python"]
def longestLength(words):
    x=max(words,key=len)
    print("The word with the longest length is:", len(x))
longestLength(a)
# Out:
# The word with the longest length is: 6

# %%
#7 Python program to sort (ascending and descending) a dictionary by value
my_dict = {2: 'Banana', 1: 'Apple', 4: 'Dragon fruit', 3: 'Cherry'}
sorted_dict = sorted(my_dict.items(), 
  key = lambda kv: kv[1])
print("Sorted dictionary is :", sorted_dict)
# Out:
# Sorted dictionary is : [(1, 'Apple'), (2, 'Banana'), (3, 'Cherry'), (4, 'Dragon fruit')]

# %%
#8 Write a Python program to add key to a dictionary
dict = {0: 10, 1: 20}
dict[2] = 30
print("Updated Dict is:", dict)
# Out:
# Updated Dict is: {0: 10, 1: 20, 2: 30}

# %%
#9 Python program to get a list, sorted in increasing order by the last element in each tuple from a given list of non-empty tuples
def last(n):
    return n[-1]
def sort_list_last(tuples):
    return sorted(tuples, key=last)
print(sort_list_last([(1, 9), (4, 2), (2, 6), (3, 4)]))
# Out:
# [(4, 2), (3, 4), (2, 6), (1, 9)]

# %%
#2.1 Write a Python program to create a class representing a Circle
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius
    
    # Calculate and return the area of the circle using the formula: π * r^2
    def calculate_circle_area(self):
        return math.pi * self.radius**2
    
    # Calculate and return the perimeter (circumference) of the circle using the formula: 2π * r
    def calculate_circle_perimeter(self):
        return 2 * math.pi * self.radius

radius = float(input("Input the radius of the circle: "))
circle = Circle(radius)
area = circle.calculate_circle_area()
perimeter = circle.calculate_circle_perimeter()
print("Area of the circle:",area)
print("Perimeter of the circle:", perimeter)
# Out:
# Input the radius of the circle:  8.5
# Area of the circle: 226.98006922186255
# Perimeter of the circle: 53.40707511102649

# %%
#2.2 Python program to create a person class
class Person:
    def __init__(self, name, country, date_of_birth):
        self.name = name
        self.country = country
        self.date_of_birth = date_of_birth
 
person1 = Person("Pritam", "India", '1994/06/10')

print("Name:", person1.name)
print("Country:", person1.country)
print("Country:", person1.date_of_birth)
# Out:
# Name: Pritam
# Country: India
# Country: 1994/06/10

# %%
#2.2.2 Implement a method to determine age
x=int(input("Enter year of birth: "))
y=2024
z=y-x
if x<2000:
    a=(2000-x)+24
    print("Age is: ",a)
else:
    print("Age is: ",z)
# Out:
# Enter year of birth:  1994
# Age is:  30

# %%
#3 Write a Python program to create a calculator class
class Calculator:
    def add(self, x, y):
        return x + y

    def subtract(self, x, y):
        return x - y

    def multiply(self, x, y):
        return x * y

    def divide(self, x, y):
        if y != 0:
            return x / y
        else:
            return ("Cannot divide by zero.")

calculator = Calculator()
result = calculator.add(120, 245)
print("Addition:", result)
result = calculator.subtract(68, 24)
print("Subtraction:", result)
result = calculator.multiply(28, 5)
print("Multiplication:", result)
result = calculator.divide(235, 10)
print("Division:", result)
# Out:
# Addition: 365
# Subtraction: 44
# Multiplication: 140
# Division: 23.5

# %%
#2.4 Python program to create a class that represents a shape
import math

class Shape:
    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    # Calculate and return the area of the circle using the formula: π * r^2
    def calculate_area(self):
        return math.pi * self.radius**2

    # Calculate and return the perimeter of the circle using the formula: 2π * r
    def calculate_perimeter(self):
        return 2 * math.pi * self.radius

class square(Shape):
    def __init__(self, side):
        self.side = side

    # Calculate and return the area of the square using the formula: side * side
    def calculate_area(self):
        return self.side * self.side

    # Calculate and return the perimeter of the square using the formula: 4 * side
    def calculate_perimeter(self):
        return 4 * self.side


class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3):
        self.base = base
        self.height = height
        self.side1 = side1
        self.side2 = side2
        self.side3 = side3

    # Calculate and return the area of the triangle using the formula: 0.5 * base * height
    def calculate_area(self):
        return 0.5 * self.base * self.height

    # Calculate and return the perimeter of the triangle by adding the lengths of its three sides
    def calculate_perimeter(self):
        return self.side1 + self.side2 + self.side3

r = 10
circle = Circle(r)
circle_area = circle.calculate_area()
circle_perimeter = circle.calculate_perimeter()
print("Radius of the circle:", r)
print("Circle Area:", circle_area)
print("Circle Perimeter:", circle_perimeter)


side = 7
square = square(side)
square_area = square.calculate_area()
square_perimeter = square.calculate_perimeter()

print("\nSquare: side =",side)
print("Square Area:", square_area)
print("Square Perimeter:", square_perimeter)

base = 5
height = 6
s1 = 7
s2 = 6
s3 = 8

# Print the results for the Triangle
print("\nTriangle: Base =", base, " Height =", height, " side1 =", s1, " side2 =", s2, " side3 =", s3)
triangle = Triangle(base, height, s1, s2, s3)
triangle_area = triangle.calculate_area()
triangle_perimeter = triangle.calculate_perimeter()
print("Triangle Area:", triangle_area)
print("Triangle Perimeter:", triangle_perimeter)
# Out:
# Radius of the circle: 10
# Circle Area: 314.1592653589793
# Circle Perimeter: 62.83185307179586
#
# Square: side = 7
# Square Area: 49
# Square Perimeter: 28
#
# Triangle: Base = 5  Height = 6  side1 = 7  side2 = 6  side3 = 8
# Triangle Area: 15.0
# Triangle Perimeter: 21

# %%
#2.5 a Python class named Student with two attributes student_name, marks
class student:
    def __init__(self, name, mark):
        self.name = name
        self.mark = mark
student1 = student("Sujay Roy","94")
setattr(student, 'mark', '96')  
print("Name:", student1.name)
print("Old marks:", student1.mark)
print("New marks: " +student.mark)
# Out:
# Name: Sujay Roy
# Old marks: 94
# New marks: 96
